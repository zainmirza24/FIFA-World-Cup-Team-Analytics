# %% [markdown]
# # QUESTION

# %% [markdown]
# What team has the strongest defense? midfield? and Offense PLAYERS?

# %%
#load df 
import pandas as pd
import numpy as np 
import seaborn as sns
df = pd.read_csv("/Users/Mirzafamily/Desktop/DS311-GroupProject/sport_data_description_tasks/fifa_worldcup.csv")
df
# Out:
#              date       home_team     away_team home_team_continent  \
# 0      1993-08-08         Bolivia       Uruguay       South America
# 1      1993-08-08          Brazil        Mexico       South America
# 2      1993-08-08         Ecuador     Venezuela       South America
# 3      1993-08-08          Guinea  Sierra Leone              Africa
# 4      1993-08-08        Paraguay     Argentina       South America
# ...           ...             ...           ...                 ...
# 23916  2022-06-14         Moldova       Andorra              Europe
# 23917  2022-06-14   Liechtenstein        Latvia              Europe
# 23918  2022-06-14           Chile         Ghana       South America
# 23919  2022-06-14           Japan       Tunisia                Asia
# 23920  2022-06-14  Korea Republic         Egypt                Asia
#
#       away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 0           South America                   59                   22
# ...

# %%
import matplotlib.pyplot as plt

# %%
dfh_argentina = df.loc[df['home_team'] == 'Argentina'] #only argentina home games 
df2 = dfh_argentina.fillna(0) #replace NA with 0 
df2
# Out:
#              date  home_team  away_team home_team_continent  \
# 15     1993-08-22  Argentina       Peru       South America
# 22     1993-08-29  Argentina   Paraguay       South America
# 27     1993-09-05  Argentina   Colombia       South America
# 129    1993-11-17  Argentina  Australia       South America
# 164    1993-12-15  Argentina    Germany       South America
# ...           ...        ...        ...                 ...
# 23158  2021-10-14  Argentina       Peru       South America
# 23306  2021-11-16  Argentina     Brazil       South America
# 23454  2022-02-01  Argentina   Colombia       South America
# 23521  2022-03-25  Argentina  Venezuela       South America
# 23741  2022-06-05  Argentina    Estonia       South America
#
#       away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 15          South America                    5                   70
# 22          South America                    5                   67
# ...

# %%
df_anhad = df2[["home_team_goalkeeper_score","home_team_mean_defense_score",
                "home_team_mean_offense_score" ]].mean()
df_anhad
# Out:
# home_team_goalkeeper_score      51.710526
# home_team_mean_defense_score    53.067895
# home_team_mean_offense_score    56.750526
# dtype: float64

# %%
df['tournament'].unique()
# Out:
# array(['FIFA World Cup qualification', 'Friendly',
#        'African Cup of Nations qualification', 'Amílcar Cabral Cup',
#        'CFU Caribbean Cup qualification',
#        'United Arab Emirates Friendship Tournament',
#        'Malta International Tournament', 'Lunar New Year Cup',
#        'African Cup of Nations', 'CFU Caribbean Cup',
#        'UEFA Euro qualification', 'Kirin Cup', 'FIFA World Cup',
#        'Oceania Nations Cup qualification', 'Baltic Cup', 'Gulf Cup',
#        'Simba Tournament', 'CECAFA Cup', 'Confederations Cup',
#        'Dynasty Cup', "King's Cup", 'Nehru Cup', 'SAFF Cup',
#        'Copa Paz del Chaco', 'Korea Cup', 'USA Cup', 'Copa América',
#        'Merdeka Tournament', 'South Pacific Games', 'UNCAF Cup',
#        'Oceania Nations Cup', 'Windward Islands Tournament', 'Gold Cup',
#        'AFC Asian Cup qualification', 'UEFA Euro', 'AFF Championship',
#        'AFC Asian Cup', 'King Hassan II Tournament',
# ...

# %%
df_wc = df[df['tournament']=='FIFA World Cup']
df_wc.head(60) #This df has only WC matches, which is what we select for our analysis
# Out:
#             date            home_team            away_team  \
# 385   1994-06-17              Germany              Bolivia
# 386   1994-06-17                Spain       Korea Republic
# 387   1994-06-18             Colombia              Romania
# 388   1994-06-18                Italy  Republic of Ireland
# 389   1994-06-18                  USA          Switzerland
# 390   1994-06-19              Belgium              Morocco
# 391   1994-06-19             Cameroon               Sweden
# 392   1994-06-19               Norway               Mexico
# 393   1994-06-20               Brazil               Russia
# 394   1994-06-20          Netherlands         Saudi Arabia
# 395   1994-06-21            Argentina               Greece
# 396   1994-06-21              Germany                Spain
# 397   1994-06-21              Nigeria             Bulgaria
# 398   1994-06-22              Romania          Switzerland
# 399   1994-06-22                  USA             Colombia
# ...

# %%
sns.set_style('darkgrid')
sns.distplot(a=df['home_team_score']);
# Out:
# /Users/Mirzafamily/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.histplot(data=df['home_team_score'], kde=True);

# %%
sns.set_style('darkgrid')
sns.distplot(a=df['away_team_scor///e']);
# Out:
# /Users/Mirzafamily/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.histplot(data = df['away_team_score'], kde = True);

# %% [markdown]
# Can we quantify those stats?

# %% [markdown]
# How do we define strongest?
